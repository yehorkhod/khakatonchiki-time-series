# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
df: pd.DataFrame = pd.read_parquet("data.parquet")
df
# Out:
#                        Date   Series1   Series2   Series3   Series4   Series5  \
# 0       2012-01-01 00:00:00  0.458882 -1.358177  1.893863  1.022005 -1.810638
# 1       2012-01-01 00:01:00  0.398794 -1.356111  2.011162  1.104435 -1.807173
# 2       2012-01-01 00:02:00  0.480416 -1.354050  2.116713  1.134004 -1.803721
# 3       2012-01-01 00:03:00  0.319643 -1.351994  1.987292  0.996250 -1.800283
# 4       2012-01-01 00:04:00  0.361104 -1.349943  2.059825  1.041442 -1.796859
# ...                     ...       ...       ...       ...       ...       ...
# 938367  2013-10-13 15:27:00 -0.763961 -1.670369  1.632822  0.327631 -1.465975
# 938368  2013-10-13 15:28:00 -0.929016 -1.799173  1.903091  0.607440 -1.464328
# 938369  2013-10-13 15:29:00 -1.058803 -1.798737  1.809294  0.673262 -1.462685
# 938370  2013-10-13 15:30:00 -0.996506 -1.798323  1.675207  0.526339 -1.461045
# 938371  2013-10-13 15:31:00 -0.921254 -1.797929  1.805300  0.599747 -1.459408
#
#          Series6
# 0      -0.792524
# 1      -0.726880
# 2      -0.816924
# 3      -1.010524
# 4            NaN
# ...          ...
# 938367 -2.002986
# 938368 -2.056986
# 938369 -1.881761
# 938370 -1.879009
# 938371 -1.933551
#
# [938372 rows x 7 columns]

# %%
df.describe()
# Out:
#              Series1        Series2        Series3        Series4  \
# count  892283.000000  892839.000000  892434.000000  892505.000000
# mean       -0.084584      -0.048724       0.087915       0.035469
# std         1.439332       1.454150       1.472772       1.466969
# min       -10.886144     -12.837726     -15.252152     -15.302137
# 25%        -1.156802      -1.063963      -0.929229      -0.982691
# 50%        -0.166540      -0.065886       0.116948       0.040032
# 75%         0.976164       0.974876       1.068746       1.061908
# max        24.358037      15.891363      13.418575      13.147020
#
#              Series5        Series6
# count  892842.000000  892759.000000
# mean       -0.063931      -0.186465
# std         1.402913       1.449497
# min       -37.920965      -9.585980
# 25%        -1.103449      -1.244107
# 50%        -0.173345      -0.309015
# 75%         0.939010       0.872775
# max        18.314306      12.423665

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 938372 entries, 0 to 938371
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Date     938372 non-null  object
#  1   Series1  892283 non-null  float64
#  2   Series2  892839 non-null  float64
#  3   Series3  892434 non-null  float64
#  4   Series4  892505 non-null  float64
#  5   Series5  892842 non-null  float64
#  6   Series6  892759 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 50.1+ MB

# %% [markdown]
# # Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set up a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(12, 8))
axes = axes.flatten()  # make it easier to index

for idx, column in enumerate(df.columns[1:]):
    axes[idx].plot(df[column], linewidth=1)
    axes[idx].set_title(column)
    axes[idx].grid(True)

plt.tight_layout()
plt.show()

# %%
# Compute correlation matrix
corr = df.drop(columns=["Date"]).corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
